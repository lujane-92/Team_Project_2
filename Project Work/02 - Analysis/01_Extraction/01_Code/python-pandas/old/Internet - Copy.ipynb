# %% [markdown]
# # 1. Splinter

# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
##url = 'http://quotes.toscrape.com/'
##browser.visit(url)

# %%
##for x in range(1, 6):

    ##html = browser.html
    ##soup = BeautifulSoup(html, 'html.parser')

    ##quotes = soup.find_all('span', class_='text')

    ##for quote in quotes:
        ##print('page:', x, '-------------')
        ##print(quote.text)

    ##browser.click_link_by_partial_text('Next')

# %%
url = 'https://ourworldindata.org/internet#all-charts-preview'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

blockColumn = soup.find('div', class_='wp-block-column')

print(blockColumn.prettify())
# Out:
# <div class="wp-block-column">
#  <ul>
#   <li class="active">
#    <a href="#all-charts-preview">
#     Broadband subscriptions per 100 people
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Correlation between internet usage and mean years of schooling
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Correlation between internet users (as a share of the population) and GDP per capita
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Cost of 1GB of mobile data (% of average income)
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Daily hours spent with digital media
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Daily time spent on the internet by young people
#    </a>
#   </li>
#   <li class="">
#    <a href="#all-charts-preview">
#     Internet users by world region
#    </a>
#   </li>
#   <li class="">
# ...

# %%
anchor = block.find_all('a')
#print('a: ' + a.text)

# %%
for a in anchor:
    print(a)
# Out:
# <a href="#all-charts-preview">Broadband subscriptions per 100 people</a>
# <a href="#all-charts-preview">Correlation between internet usage and mean years of schooling</a>
# <a href="#all-charts-preview">Correlation between internet users (as a share of the population) and GDP per capita</a>
# <a href="#all-charts-preview">Cost of 1GB of mobile data (% of average income)</a>
# <a href="#all-charts-preview">Daily hours spent with digital media</a>
# <a href="#all-charts-preview">Daily time spent on the internet by young people</a>
# <a href="#all-charts-preview">Internet users by world region</a>
# <a href="#all-charts-preview">Mobile cellular subscriptions</a>
# <a href="#all-charts-preview">Number of internet users by country</a>
# <a href="#all-charts-preview">Percentage of individuals using the internet by country</a>
# <a href="#all-charts-preview">Percentage of young people engaging in social networking online</a>
# ...

# %%
for a in anchor:
    link = a['href']
    print(link)
# Out:
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview
# #all-charts-preview

# %%
for a in anchor:
    link = a['href']
    print('link: ' + link)
    
    try:
        browser.click_link_by_partial_text('link')
    
    except:
        print('Not found')
        print('---------')
# Out:
# link: #all-charts-preview
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-5f7d2905cec2> in <module>
#       2     link = a['href']
#       3     print('link: ' + link)
# ----> 4     print(a.text())
#       5
#       6     try:
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # 2. Json

# %%
# Dependencies
import requests

# %%
#url = 'https://ourworldindata.org/grapher/data/variables/2209+41+72+123.json?v=1'

url = 'https://ourworldindata.org/grapher/data/variables/99383.json?v=3'

# %%
get_data = requests.get(url).json()

# %%
get_data
# Out:
# {'variables': {'99383': {'years': [1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
#     1990,
# ...
