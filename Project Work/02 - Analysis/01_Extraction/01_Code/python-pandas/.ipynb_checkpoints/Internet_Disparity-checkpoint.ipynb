# %% [markdown]
# # 1. Json

# %%
# Dependencies
import json
import requests
import pandas as pd
from pprint import pprint
from bs4 import BeautifulSoup
from splinter import Browser

# %% [markdown]
# # 2. URL: https://ourworldindata.org/internet#all-charts-preview

# %% [markdown]
# # 2.9. Number of internet users by country

# %% [markdown]
# ## 2.9.1. Country Data

# %%
url = 'https://ourworldindata.org/grapher/data/variables/99383.json?v=3'
Get_Data = requests.get(url).json()
#pprint(get_data)

# %%
Country_ID = []
Country_Name = []
Country_Code = []

for E in Get_Data['entityKey']:
    Country_ID.append(E)
    Country_Name.append(Get_Data['entityKey'][E]['name'])
    Country_Code.append(Get_Data['entityKey'][E]['code'])

# %%
#print(Country_ID)
len(Country_ID)
# Out:
# 193

# %%
#print(Country_Code)
len(Country_Code)
# Out:
# 193

# %%
#print(Country_Name)
len(Country_Name)
# Out:
# 193

# %%
Country_df = pd.DataFrame({
    'Country_ID'    : Country_ID,
    'Country_Code'  : Country_Code,
    'Country_Name'  : Country_Name
})

# %%
Country_df
# Out:
#     Country_ID Country_Code        Country_Name
# 0            1          GBR      United Kingdom
# 1            2          IRL             Ireland
# 2            3          FRA              France
# 3            4          BEL             Belgium
# 4            5          NLD         Netherlands
# ..         ...          ...                 ...
# 188        259          SLV         El Salvador
# 189        262          MAC               Macao
# 190        279          CUW             Curacao
# 191        289         None  Sub-Saharan Africa
# 192        355     OWID_WRL               World
#
# [193 rows x 3 columns]

# %%
# Export to CSV
Country_df.to_csv("../../02_Data_Output/Internet_Users_Country_Countries_df.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 2.9.2 Values

# %%
Country_ID = []
Number_Of_Internet_Users_By_Country = []
Country_Years = []


IDs      = Get_Data['variables']['99383']['entities'] 
Values   = Get_Data['variables']['99383']['values']
Years    = Get_Data['variables']['99383']['years']
    
    
for I in IDs:
    Country_ID.append(I)

for V in Values:
    Number_Of_Internet_Users_By_Country.append(V)
    
for Y in Years:
    Country_Years.append(Y)

# %%
#print(Country_ID)

# %%
Country_Values_df = pd.DataFrame({
    'Country_ID'     : Country_ID,
    'Country_Years'  : Country_Years,
    'Number_Of_Internet_Users_By_Country'  : Number_Of_Internet_Users_By_Country
})

# %%
Country_Values_df
# Out:
#       Country_ID  Country_Years  Number_Of_Internet_Users_By_Country
# 0             15           1990                                    0
# 1             16           1990                                    0
# 2             17           1990                                    0
# 3             19           1990                                    0
# 4             20           1990                                    0
# ...          ...            ...                                  ...
# 4531          75           2017                             36515273
# 4532          74           2017                               963813
# 4533          71           2017                              6400330
# 4534          70           2017                             52229607
# 4535          72           2017                              8913210
#
# [4536 rows x 3 columns]

# %%
# Export to CSV
Country_Values_df.to_csv("../../02_Data_Output/Internet_Users_Country_Values_df.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# # 2.16. Share of the population using the Internet

# %% [markdown]
# ## 2.16.1 Country Data

# %%
url = 'https://ourworldindata.org/grapher/data/variables/2683.json?v=7'
Get_Data = requests.get(url).json()
#pprint(get_data)
#pprint(Get_Data['variables'])

# %%
Country_ID = []
Country_Name = []
Country_Code = []

for E in Get_Data['entityKey']:
    Country_ID.append(E)
    Country_Name.append(Get_Data['entityKey'][E]['name'])
    Country_Code.append(Get_Data['entityKey'][E]['code'])

# %%
#print(Country_ID)
len(Country_ID)
# Out:
# 258

# %%
#print(Country_Code)
len(Country_Code)
# Out:
# 258

# %%
#print(Country_Name)
len(Country_Name)
# Out:
# 258

# %%
Country_df = pd.DataFrame({
    'Country_ID'    : Country_ID,
    'Country_Code'  : Country_Code,
    'Country_Name'  : Country_Name
})

# %%
Country_df
# Out:
#     Country_ID Country_Code                             Country_Name
# 0            1          GBR                           United Kingdom
# 1            2          IRL                                  Ireland
# 2            3          FRA                                   France
# 3            4          BEL                                  Belgium
# 4            5          NLD                              Netherlands
# ..         ...          ...                                      ...
# 253      34681         None       Europe & Central Asia (IDA & IBRD)
# 254      34682         None   Latin America & Caribbean (IDA & IBRD)
# 255      34683         None  Middle East & North Africa (IDA & IBRD)
# 256      34684         None          Sub-Saharan Africa (IDA & IBRD)
# 257      54362         None                     Syrian Arab Republic
#
# [258 rows x 3 columns]

# %%
# Export to CSV
Country_df.to_csv("../../02_Data_Output/Share_Population_Usage_Country_df.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 2.16.2 Values

# %%
Country_ID = []
Share_of_The_Population_Using_The_Internet_Country = []
Country_Years = []


IDs      = Get_Data['variables']['2683']['entities'] 
Values   = Get_Data['variables']['2683']['values']
Years    = Get_Data['variables']['2683']['years']
    
    
for I in IDs:
    Country_ID.append(I)

for V in Values:
    Share_of_The_Population_Using_The_Internet_Country.append(V)
    
for Y in Years:
    Country_Years.append(Y)

# %%
#print(Country_ID)

# %%
Country_Values_df = pd.DataFrame({
    'Country_ID'     : Country_ID,
    'Country_Years'  : Country_Years,
    'Share_of_The_Population_Using_The_Internet_Country'  : Share_of_The_Population_Using_The_Internet_Country
})

# %%
Country_Values_df
# Out:
#       Country_ID  Country_Years  \
# 0             36           1960
# 1             41           1960
# 2            206           1960
# 3            211           1960
# 4          54362           1960
# ...          ...            ...
# 6051          75           2017
# 6052          74           2017
# 6053          71           2017
# 6054          70           2017
# 6055          72           2017
#
#       Share_of_The_Population_Using_The_Internet_Country
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 6051                                          52.891929
# 6052                                          12.360225
# 6053                                          55.500000
# ...

# %%
# Export to CSV
Country_Values_df.to_csv("../../02_Data_Output/Share_Population_Usage_Values_df.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# # 3.URL: https://www.internetworldstats.com/stats1.htm

# %% [markdown]
# ## 3.1. World

# %%
url = 'https://www.internetworldstats.com/stats.htm'
table = pd.read_html(url, header=0)
Internet_Usage_World = table[5]
Internet_Usage_World
# Out:
#   WORLD INTERNET USAGE AND POPULATION STATISTICS2020 Year-Q1 Estimates  \
# 0                                      World Regions
# 1                                             Africa
# 2                                               Asia
# 3                                             Europe
# 4                          Latin America / Caribbean
# 5                                        Middle East
# 6                                      North America
# 7                                Oceania / Australia
# 8                                        WORLD TOTAL
# 9  NOTES: (1) Internet Usage and World Population...
#
#   WORLD INTERNET USAGE AND POPULATION STATISTICS2020 Year-Q1 Estimates.1  \
# 0                            Population ( 2020 Est.)
# 1                                         1340598447
# 2                                         4294516659
# 3                                          834995197
# 4                                          658345826
# ...

# %%
# Export to CSV
Internet_Usage_World.to_csv("../../02_Data_Output/Internet_Usage_World.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.2. Africa

# %%
url = 'https://www.internetworldstats.com/stats1.htm'
table = pd.read_html(url, header=0)
Internet_Usage_Africa = table[5]
Internet_Usage_Africa.head()
# Out:
#   AFRICA 2020 POPULATION AND INTERNET USERS STATISTICS  \
# 0                                             AFRICA
# 1                                            Algeria
# 2                                             Angola
# 3                                              Benin
# 4                                           Botswana
#
#   AFRICA 2020 POPULATION AND INTERNET USERS STATISTICS.1  \
# 0                            Population  (2020 Est.)
# 1                                           43851044
# 2                                           32866272
# 3                                           12123200
# 4                                            2351627
#
#   AFRICA 2020 POPULATION AND INTERNET USERS STATISTICS.2  \
# 0                         InternetUsers  31-Dec-2000
# 1                                              50000
# 2                                              30000
# 3                                              15000
# ...

# %%
# Export to CSV
Internet_Usage_Africa.to_csv("../../02_Data_Output/Internet_Usage_Africa.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.3. Americas

# %%
url = 'https://www.internetworldstats.com/stats2.htm'
table = pd.read_html(url, header=0)
Internet_Usage_Americas = table[4]
Internet_Usage_Americas.head()
# Out:
#   Internet Usage,  Facebook Subscribers and Population  Statistics for all the Americas World Region Countries  March 31, 2020  \
# 0                                       THE AMERICAS
# 1                                           Anguilla
# 2                                  Antigua & Barbuda
# 3                                          Argentina
# 4                                              Aruba
#
#   Internet Usage,  Facebook Subscribers and Population  Statistics for all the Americas World Region Countries  March 31, 2020.1  \
# 0                          Population  ( 2020 Est. )
# 1                                              14909
# 2                                             103050
# 3                                           44688864
# 4                                             105670
#
#   Internet Usage,  Facebook Subscribers and Population  Statistics for all the Americas World Region Countries  March 31, 2020.2  \
# ...

# %%
# Export to CSV
Internet_Usage_Americas.to_csv("../../02_Data_Output/Internet_Usage_Americas.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.4. Asia

# %%
url = 'https://www.internetworldstats.com/stats3.htm'
table = pd.read_html(url, header=0)
Internet_Usage_Asia = table[8]
Internet_Usage_Asia.head()
# Out:
#   ASIA  INTERNET USE, POPULATION STATISTICS DATA  AND FACEBOOK DATA - JANUARY 31, 2020  \
# 0                                               ASIA
# 1                                         Afganistan
# 2                                            Armenia
# 3                                         Azerbaijan
# 4                                         Bangladesh
#
#   ASIA  INTERNET USE, POPULATION STATISTICS DATA  AND FACEBOOK DATA - JANUARY 31, 2020.1  \
# 0                           Population  ( 2020 Est.)
# 1                                           38928346
# 2                                            2963243
# 3                                           10139177
# 4                                          164689383
#
#   ASIA  INTERNET USE, POPULATION STATISTICS DATA  AND FACEBOOK DATA - JANUARY 31, 2020.2  \
# 0                       Internet Users,  (Year 2000)
# 1                                               1000
# 2                                              30000
# ...

# %%
# Export to CSV
Internet_Usage_Asia.to_csv("../../02_Data_Output/Internet_Usage_Asia.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.5. Europe

# %%
url = 'https://www.internetworldstats.com/stats4.htm'
table = pd.read_html(url, header=0)
Internet_Usage_Europe = table[8]
Internet_Usage_Europe.head()
# Out:
#   Internet Stats and Facebook  Usage in EuropeJune 2019 Statistics  \
# 0                                             EUROPE
# 1                                            Albania
# 2                                            Andorra
# 3                                            Austria
# 4                                            Belarus
#
#   Internet Stats and Facebook  Usage in EuropeJune 2019 Statistics.1  \
# 0                          Population  ( 2019 Est. )
# 1                                            2938428
# 2                                              77072
# 3                                            8766201
# 4                                            9433874
#
#   Internet Stats and Facebook  Usage in EuropeJune 2019 Statistics.2  \
# 0                      Internet Users,  30-June-2019
# 1                                            2160000
# 2                                              76242
# 3                                            7708997
# ...

# %%
# Export to CSV
Internet_Usage_Europe.to_csv("../../02_Data_Output/Internet_Usage_Europe.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.6. European Union

# %%
url = 'https://www.internetworldstats.com/stats9.htm'
table = pd.read_html(url, header=0)
Internet_Usage_EuropeanUnion = table[9]
Internet_Usage_EuropeanUnion.head()
# Out:
#   Internet Users in the European Union - 2019  \
# 0                              EUROPEAN UNION
# 1                                     Austria
# 2                                     Belgium
# 3                                    Bulgaria
# 4                                     Croatia
#
#   Internet Users in the European Union - 2019.1  \
# 0                      Population ( 2019 Est. )
# 1                                       8766201
# 2                                      11562784
# 3                                       6988739
# 4                                       4140148
#
#   Internet Users in the European Union - 2019.2  \
# 0                  Internet Users, 30-June-2019
# 1                                       7708997
# 2                                      10857126
# 3                                       4663065
# 4                                       3787838
#
#   Internet Users in the European Union - 2019.3  \
# ...

# %%
# Export to CSV
Internet_Usage_EuropeanUnion.to_csv("../../02_Data_Output/Internet_Usage_EuropeanUnion.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.7. Middle East

# %%
url = 'https://www.internetworldstats.com/stats5.htm'
table = pd.read_html(url, header=0)
Internet_Usage_MiddleEast = table[6]
Internet_Usage_MiddleEast.head()
# Out:
#   Middle East Internet Users, Population and Facebook  Statistics 2020  \
# 0                                        MIDDLE EAST
# 1                                            Bahrain
# 2                                               Iran
# 3                                               Iraq
# 4                                             Israel
#
#   Middle East Internet Users, Population and Facebook  Statistics 2020.1  \
# 0                          Population  ( 2020 Est. )
# 1                                            1701575
# 2                                           83992949
# 3                                           40222493
# 4                                            8655535
#
#   Middle East Internet Users, Population and Facebook  Statistics 2020.2  \
# 0                                Users, in  Dec/2000
# 1                                              40000
# 2                                             250000
# ...

# %%
# Export to CSV
Internet_Usage_MiddleEast.to_csv("../../02_Data_Output/Internet_Usage_MiddleEast.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# ## 3.8. Oceania

# %%
url = 'https://www.internetworldstats.com/stats6.htm'
table = pd.read_html(url, header=0)
Internet_Usage_Oceania = table[7]
Internet_Usage_Oceania.head()
# Out:
#   Internet Usage and Population Statistics for Oceania - 2019  \
# 0                                            OCEANIA
# 1                                     American Samoa
# 2                                         Antarctica
# 3                                          Australia
# 4                              Australia, Ext. Terr.
#
#   Internet Usage and Population Statistics for Oceania - 2019.1  \
# 0                            Population  (2019 Est.)
# 1                                              55727
# 2                                               2700
# 3                                           25088636
# 4                                               1651
#
#   Internet Usage and Population Statistics for Oceania - 2019.2  \
# 0                                Users, in  Dec/2000
# 1                                                NaN
# 2                                                NaN
# 3                                            6600000
# ...

# %%
# Export to CSV
Internet_Usage_Oceania.to_csv("../../02_Data_Output/Internet_Usage_Oceania.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# # 4. URL: http://api.worldbank.org/v2/

# %%
# Dependencies
import pandas as pd
from pandas import DataFrame
import requests
import json
from pandas.io.json import json_normalize

url = "http://api.worldbank.org/v2/"
format = "json"

# Get country information in JSON format
countries_response = requests.get(f"{url}country/?per_page=304&format={format}").json()
#http://api.worldbank.org/countries/?per_page=300&format=json

# First element is general information, second is countries themselves
countries = countries_response[1]

# %%
print (countries[0])
# Out:
# {'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}

# %%
# Report the names
# Name, Region, Income Level, Capital City, Longitude, Latitude

#for country in countries:
    #print(country["name"]) 
    #print(country["region"]["value"])

# %%
Lat_Long_Coordinates_df = DataFrame(countries)
Lat_Long_Coordinates_df
# Out:
#       id iso2Code                                               name  \
# 0    ABW       AW                                              Aruba
# 1    AFG       AF                                        Afghanistan
# 2    AFR       A9                                             Africa
# 3    AGO       AO                                             Angola
# 4    ALB       AL                                            Albania
# ..   ...      ...                                                ...
# 299  XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# 300  YEM       YE                                        Yemen, Rep.
# 301  ZAF       ZA                                       South Africa
# 302  ZMB       ZM                                             Zambia
# 303  ZWE       ZW                                           Zimbabwe
#
#                                                 region  \
# 0    {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# ...

# %%
# Export to CSV
Lat_Long_Coordinates_df.to_csv("../../02_Data_Output/Lat_Long_Coordinates.csv",
                   index=False, 
                   header=True
                  )

# %% [markdown]
# # 5. URL: https://data.worldbank.org/indicator/IT.NET.USER.ZS

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url='http://api.worldbank.org/v2/en/indicator/IT.NET.USER.ZS?downloadformat=excel'
browser.visit(url)

# %% [markdown]
# # 6 URL: https://thewebindex.org/downloads/

# %% [markdown]
# ## 6.1 Click button

# %%
#from selenium import webdriver
#from selenium.webdriver.chrome.options import Options

#options = webdriver.ChromeOptions() 
#options.add_argument("download.default_directory= ../../02_Data_Output/newfile.xls")
#driver = webdriver.Chrome(chrome_options=options)

#url='https://thewebindex.org/downloads/'
#driver.get(url)

#driver.click_link_by_partial_text('XLS')

# %%
url='https://thewebindex.org/downloads/'
browser.visit(url)

browser.click_link_by_partial_text('XLS')
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,

# %% [markdown]
# # 7. URL: https://www.comparethemarket.com/broadband/content/global-broadband-index/

# %% [markdown]
# ## 7.1 Html Scraping

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url='https://www.comparethemarket.com/broadband/content/global-broadband-index/'
browser.visit(url)

# %%
raw_data_html = browser.find_by_id('rows').html
#print(raw_data_html)

# %%
raw_data_text = browser.find_by_id('rows').text
#print(type(raw_data_text))
print(raw_data_text)
# Out:
# Country Avg. Monthly Cost Avg. Download Speed Avg. Upload Speed Time to Download One Hour of Netflix
# Singapore £39.84 185.25 Mbps 192.08 Mbps 16 seconds
# Iceland £60.56 153.3 Mbps 155.46 Mbps 20 seconds
# South Korea £25.51 114.31 Mbps 90.2 Mbps 26 seconds
# Hungary £14.51 108.78 Mbps 44.44 Mbps 28 seconds
# United States £53.48 107.28 Mbps 37.11 Mbps 28 seconds
# Sweden £44.23 106.76 Mbps 72.98 Mbps 28 seconds
# Spain £33.48 105.03 Mbps 87.51 Mbps 29 seconds
# Switzerland £63.20 104.2 Mbps 65.37 Mbps 29 seconds
# Luxembourg £56.21 101.48 Mbps 65.5 Mbps 30 seconds
# Norway £58.40 98.72 Mbps 75.67 Mbps 30 seconds
# France £24.60 96.14 Mbps 49.05 Mbps 31 seconds
# Denmark £40.38 91.27 Mbps 67.11 Mbps 33 seconds
# Canada £45.55 91.05 Mbps 38.57 Mbps 33 seconds
# Japan £29.35 88.97 Mbps 97.52 Mbps 34 seconds
# Netherlands £46.79 86.14 Mbps 41.77 Mbps 35 seconds
# New Zealand £46.43 83.96 Mbps 47.63 Mbps 36 seconds
# Portugal £48.31 73.65 Mbps 39.67 Mbps 41 seconds
# ...

# %%
Cost_Speed_By_Country = raw_data_text.splitlines()

# %%
Cost_Speed_By_Country
# Out:
# ['Country Avg. Monthly Cost Avg. Download Speed Avg. Upload Speed Time to Download One Hour of Netflix',
#  'Singapore £39.84 185.25 Mbps 192.08 Mbps 16 seconds',
#  'Iceland £60.56 153.3 Mbps 155.46 Mbps 20 seconds',
#  'South Korea £25.51 114.31 Mbps 90.2 Mbps 26 seconds',
#  'Hungary £14.51 108.78 Mbps 44.44 Mbps 28 seconds',
#  'United States £53.48 107.28 Mbps 37.11 Mbps 28 seconds',
#  'Sweden £44.23 106.76 Mbps 72.98 Mbps 28 seconds',
#  'Spain £33.48 105.03 Mbps 87.51 Mbps 29 seconds',
#  'Switzerland £63.20 104.2 Mbps 65.37 Mbps 29 seconds',
#  'Luxembourg £56.21 101.48 Mbps 65.5 Mbps 30 seconds',
#  'Norway £58.40 98.72 Mbps 75.67 Mbps 30 seconds',
#  'France £24.60 96.14 Mbps 49.05 Mbps 31 seconds',
#  'Denmark £40.38 91.27 Mbps 67.11 Mbps 33 seconds',
#  'Canada £45.55 91.05 Mbps 38.57 Mbps 33 seconds',
#  'Japan £29.35 88.97 Mbps 97.52 Mbps 34 seconds',
#  'Netherlands £46.79 86.14 Mbps 41.77 Mbps 35 seconds',
#  'New Zealand £46.43 83.96 Mbps 47.63 Mbps 36 seconds',
# ...

# %%
Cost_Speed_By_Country_df = pd.DataFrame({
    'Cost_Speed_By_Country' : Cost_Speed_By_Country
})

# %%
Cost_Speed_By_Country_df
# Out:
#                                 Cost_Speed_By_Country
# 0   Country Avg. Monthly Cost Avg. Download Speed ...
# 1   Singapore £39.84 185.25 Mbps 192.08 Mbps 16 se...
# 2    Iceland £60.56 153.3 Mbps 155.46 Mbps 20 seconds
# 3   South Korea £25.51 114.31 Mbps 90.2 Mbps 26 se...
# 4    Hungary £14.51 108.78 Mbps 44.44 Mbps 28 seconds
# 5   United States £53.48 107.28 Mbps 37.11 Mbps 28...
# 6     Sweden £44.23 106.76 Mbps 72.98 Mbps 28 seconds
# 7      Spain £33.48 105.03 Mbps 87.51 Mbps 29 seconds
# 8   Switzerland £63.20 104.2 Mbps 65.37 Mbps 29 se...
# 9   Luxembourg £56.21 101.48 Mbps 65.5 Mbps 30 sec...
# 10     Norway £58.40 98.72 Mbps 75.67 Mbps 30 seconds
# 11     France £24.60 96.14 Mbps 49.05 Mbps 31 seconds
# 12    Denmark £40.38 91.27 Mbps 67.11 Mbps 33 seconds
# 13     Canada £45.55 91.05 Mbps 38.57 Mbps 33 seconds
# 14      Japan £29.35 88.97 Mbps 97.52 Mbps 34 seconds
# 15  Netherlands £46.79 86.14 Mbps 41.77 Mbps 35 se...
# ...

# %%
Cost_Speed_By_Country_Slpit_df1 = Cost_Speed_By_Country_df['Cost_Speed_By_Country'].str.split(' ', expand=True)
Cost_Speed_By_Country_Slpit_df1
# Out:
#               0         1         2        3       4         5      6  \
# 0       Country      Avg.   Monthly     Cost    Avg.  Download  Speed
# 1     Singapore    £39.84    185.25     Mbps  192.08      Mbps     16
# 2       Iceland    £60.56     153.3     Mbps  155.46      Mbps     20
# 3         South     Korea    £25.51   114.31    Mbps      90.2   Mbps
# 4       Hungary    £14.51    108.78     Mbps   44.44      Mbps     28
# 5        United    States    £53.48   107.28    Mbps     37.11   Mbps
# 6        Sweden    £44.23    106.76     Mbps   72.98      Mbps     28
# 7         Spain    £33.48    105.03     Mbps   87.51      Mbps     29
# 8   Switzerland    £63.20     104.2     Mbps   65.37      Mbps     29
# 9    Luxembourg    £56.21    101.48     Mbps    65.5      Mbps     30
# 10       Norway    £58.40     98.72     Mbps   75.67      Mbps     30
# 11       France    £24.60     96.14     Mbps   49.05      Mbps     31
# ...

# %%
Cost_Speed_By_Country_Slpit_df1.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# 15    object
# 16    object
# dtype: object

# %%
Cost_Speed_By_Country_Slpit_Renamed_df1 = Cost_Speed_By_Country_Slpit_df1.rename(columns={0 : 'Col 1',
                                                                                          1 : 'Col 2',
                                                                                          2 : 'Col 3',
                                                                                          3 : 'Col 4',
                                                                                          4 : 'Col 5',
                                                                                          5 : 'Col 6', 
                                                                                          6 : 'Col 7', 
                                                                                          7 : 'Col 8', 
                                                                                          8 : 'Col 9', 
                                                                                          9 : 'Col 10', 
                                                                                          10 : 'Col 11', 
                                                                                          11 : 'Col 12', 
                                                                                          12 : 'Col 13', 
                                                                                          13 : 'Col 14', 
                                                                                          14 : 'Col 15', 
                                                                                          15 : 'Col 16', 
                                                                                          16 : 'Col 17'
                                                                                         } 
                                                                                )

# %%
Cost_Speed_By_Country_Slpit_Renamed_df1
# Out:
#           Col 1     Col 2     Col 3    Col 4   Col 5     Col 6  Col 7  \
# 0       Country      Avg.   Monthly     Cost    Avg.  Download  Speed
# 1     Singapore    £39.84    185.25     Mbps  192.08      Mbps     16
# 2       Iceland    £60.56     153.3     Mbps  155.46      Mbps     20
# 3         South     Korea    £25.51   114.31    Mbps      90.2   Mbps
# 4       Hungary    £14.51    108.78     Mbps   44.44      Mbps     28
# 5        United    States    £53.48   107.28    Mbps     37.11   Mbps
# 6        Sweden    £44.23    106.76     Mbps   72.98      Mbps     28
# 7         Spain    £33.48    105.03     Mbps   87.51      Mbps     29
# 8   Switzerland    £63.20     104.2     Mbps   65.37      Mbps     29
# 9    Luxembourg    £56.21    101.48     Mbps    65.5      Mbps     30
# 10       Norway    £58.40     98.72     Mbps   75.67      Mbps     30
# 11       France    £24.60     96.14     Mbps   49.05      Mbps     31
# ...

# %%
len(Cost_Speed_By_Country_Slpit_Renamed_df1)
# Out:
# 55

# %%
Cost_Speed_By_Country_Slpit_Filtered_df1 = Cost_Speed_By_Country_Slpit_Renamed_df1.loc[(Cost_Speed_By_Country_Slpit_df1[1] != 'Korea') & 
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'States') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'Zealand') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'Kingdom') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'Republic') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'Arabia') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'Arab') &
                                                                          (Cost_Speed_By_Country_Slpit_df1[1] != 'and')
                                                                          , :]

# %%
#Cost_Speed_By_Country_Slpit_Filtered_df1.drop(columns =['Col 11', 'Col 12', 'Col 13', 'Col 14', 'Col 15', 'Col 16']) 
Cost_Speed_By_Country_Slpit_Filtered_df1
# Out:
#           Col 1    Col 2    Col 3 Col 4   Col 5     Col 6  Col 7     Col 8  \
# 0       Country     Avg.  Monthly  Cost    Avg.  Download  Speed      Avg.
# 1     Singapore   £39.84   185.25  Mbps  192.08      Mbps     16   seconds
# 2       Iceland   £60.56    153.3  Mbps  155.46      Mbps     20   seconds
# 4       Hungary   £14.51   108.78  Mbps   44.44      Mbps     28   seconds
# 6        Sweden   £44.23   106.76  Mbps   72.98      Mbps     28   seconds
# 7         Spain   £33.48   105.03  Mbps   87.51      Mbps     29   seconds
# 8   Switzerland   £63.20    104.2  Mbps   65.37      Mbps     29   seconds
# 9    Luxembourg   £56.21   101.48  Mbps    65.5      Mbps     30   seconds
# 10       Norway   £58.40    98.72  Mbps   75.67      Mbps     30   seconds
# 11       France   £24.60    96.14  Mbps   49.05      Mbps     31   seconds
# 12      Denmark   £40.38    91.27  Mbps   67.11      Mbps     33   seconds
# ...

# %%
len(Cost_Speed_By_Country_Slpit_Filtered_df1)
# Out:
# 47

# %%
Cost_Speed_By_Country_Slpit_Filtered_df2 = Cost_Speed_By_Country_Slpit_Renamed_df1.loc[(Cost_Speed_By_Country_Slpit_df1[1] == 'Korea') | 
                                                                              (Cost_Speed_By_Country_Slpit_df1[1] == 'States') |
                                                                              (Cost_Speed_By_Country_Slpit_df1[1] == 'Zealand') |
                                                                              (Cost_Speed_By_Country_Slpit_df1[1] == 'Kingdom') |
                                                                              (Cost_Speed_By_Country_Slpit_df1[1] == 'Republic') |
                                                                              (Cost_Speed_By_Country_Slpit_df1[1] == 'Arabia')
                                                                          , :]
Cost_Speed_By_Country_Slpit_Filtered_df2
# Out:
#      Col 1     Col 2   Col 3   Col 4 Col 5  Col 6 Col 7 Col 8    Col 9 Col 10  \
# 3    South     Korea  £25.51  114.31  Mbps   90.2  Mbps    26  seconds   None
# 5   United    States  £53.48  107.28  Mbps  37.11  Mbps    28  seconds   None
# 16     New   Zealand  £46.43   83.96  Mbps  47.63  Mbps    36  seconds   None
# 27  United   Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54  seconds   None
# 35   Czech  Republic  £20.49    44.6  Mbps   23.6  Mbps     1  minute,      7
# 43   Saudi    Arabia  £75.62   29.83  Mbps  12.55  Mbps     1  minute,     41
#
#      Col 11 Col 12 Col 13 Col 14 Col 15 Col 16 Col 17
# 3      None   None   None   None   None   None   None
# 5      None   None   None   None   None   None   None
# 16     None   None   None   None   None   None   None
# 27     None   None   None   None   None   None   None
# 35  seconds   None   None   None   None   None   None
# 43  seconds   None   None   None   None   None   None

# %%
len(Cost_Speed_By_Country_Slpit_Filtered_df2)
# Out:
# 6

# %%
Cost_Speed_By_Country_Slpit_Filtered_df2['Renamed Country'] = ''
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Cost_Speed_By_Country_Slpit_Filtered_df2['Renamed Country']  = Cost_Speed_By_Country_Slpit_Filtered_df2['Col 1'].map(str) + ' ' + Cost_Speed_By_Country_Slpit_Filtered_df2['Col 2'].map(str)
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Cost_Speed_By_Country_Slpit_Filtered_df2
# Out:
#      Col 1     Col 2   Col 3   Col 4 Col 5  Col 6 Col 7 Col 8    Col 9 Col 10  \
# 3    South     Korea  £25.51  114.31  Mbps   90.2  Mbps    26  seconds   None
# 5   United    States  £53.48  107.28  Mbps  37.11  Mbps    28  seconds   None
# 16     New   Zealand  £46.43   83.96  Mbps  47.63  Mbps    36  seconds   None
# 27  United   Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54  seconds   None
# 35   Czech  Republic  £20.49    44.6  Mbps   23.6  Mbps     1  minute,      7
# 43   Saudi    Arabia  £75.62   29.83  Mbps  12.55  Mbps     1  minute,     41
#
#      Col 11 Col 12 Col 13 Col 14 Col 15 Col 16 Col 17 Renamed Country
# 3      None   None   None   None   None   None   None     South Korea
# 5      None   None   None   None   None   None   None   United States
# 16     None   None   None   None   None   None   None     New Zealand
# 27     None   None   None   None   None   None   None  United Kingdom
# 35  seconds   None   None   None   None   None   None  Czech Republic
# ...

# %%
Cost_Speed_By_Country_Slpit_Filtered_df2['Col 1'] = Cost_Speed_By_Country_Slpit_Filtered_df2['Renamed Country']
Cost_Speed_By_Country_Slpit_Filtered_df2
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              Col 1     Col 2   Col 3   Col 4 Col 5  Col 6 Col 7 Col 8  \
# 3      South Korea     Korea  £25.51  114.31  Mbps   90.2  Mbps    26
# 5    United States    States  £53.48  107.28  Mbps  37.11  Mbps    28
# 16     New Zealand   Zealand  £46.43   83.96  Mbps  47.63  Mbps    36
# 27  United Kingdom   Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54
# 35  Czech Republic  Republic  £20.49    44.6  Mbps   23.6  Mbps     1
# 43    Saudi Arabia    Arabia  £75.62   29.83  Mbps  12.55  Mbps     1
#
# ...

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df2 = Cost_Speed_By_Country_Slpit_Filtered_df2.drop(columns = ['Col 2', 'Col 12', 'Col 13', 'Col 14', 'Col 15', 'Col 16', 'Col 17', 'Renamed Country'])

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df2
# Out:
#              Col 1   Col 3   Col 4 Col 5  Col 6 Col 7 Col 8    Col 9 Col 10  \
# 3      South Korea  £25.51  114.31  Mbps   90.2  Mbps    26  seconds   None
# 5    United States  £53.48  107.28  Mbps  37.11  Mbps    28  seconds   None
# 16     New Zealand  £46.43   83.96  Mbps  47.63  Mbps    36  seconds   None
# 27  United Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54  seconds   None
# 35  Czech Republic  £20.49    44.6  Mbps   23.6  Mbps     1  minute,      7
# 43    Saudi Arabia  £75.62   29.83  Mbps  12.55  Mbps     1  minute,     41
#
#      Col 11
# 3      None
# 5      None
# 16     None
# 27     None
# 35  seconds
# 43  seconds

# %%
#Cost_Speed_By_Country_Slpit_Filtered_df1

# %%
len(Cost_Speed_By_Country_Slpit_Filtered_df1)
# Out:
# 47

# %%
Cost_Speed_By_Country_Slpit_Filtered_df1 = Cost_Speed_By_Country_Slpit_Filtered_df1.drop(columns = ['Col 11', 'Col 12', 'Col 13', 'Col 14', 'Col 15', 'Col 16', 'Col 17'])

# %%
Cost_Speed_By_Country_Slpit_Filtered_df1
# Out:
#           Col 1    Col 2    Col 3 Col 4   Col 5     Col 6  Col 7     Col 8  \
# 0       Country     Avg.  Monthly  Cost    Avg.  Download  Speed      Avg.
# 1     Singapore   £39.84   185.25  Mbps  192.08      Mbps     16   seconds
# 2       Iceland   £60.56    153.3  Mbps  155.46      Mbps     20   seconds
# 4       Hungary   £14.51   108.78  Mbps   44.44      Mbps     28   seconds
# 6        Sweden   £44.23   106.76  Mbps   72.98      Mbps     28   seconds
# 7         Spain   £33.48   105.03  Mbps   87.51      Mbps     29   seconds
# 8   Switzerland   £63.20    104.2  Mbps   65.37      Mbps     29   seconds
# 9    Luxembourg   £56.21   101.48  Mbps    65.5      Mbps     30   seconds
# 10       Norway   £58.40    98.72  Mbps   75.67      Mbps     30   seconds
# 11       France   £24.60    96.14  Mbps   49.05      Mbps     31   seconds
# 12      Denmark   £40.38    91.27  Mbps   67.11      Mbps     33   seconds
# ...

# %%
Cost_Speed_By_Country_Slpit_Filtered_df3 = Cost_Speed_By_Country_Slpit_Renamed_df1.loc[(Cost_Speed_By_Country_Slpit_df1[1] == 'and') |
                                                                                       (Cost_Speed_By_Country_Slpit_df1[1] == 'Arab')
                                                                          , :]
Cost_Speed_By_Country_Slpit_Filtered_df3
# Out:
#        Col 1 Col 2     Col 3    Col 4  Col 5 Col 6  Col 7 Col 8 Col 9  \
# 37  Trinidad   and    Tobago   £48.01   42.5  Mbps  23.15  Mbps     1
# 38    United  Arab  Emirates  £124.11  38.16  Mbps  13.56  Mbps     1
#
#      Col 10 Col 11   Col 12 Col 13 Col 14 Col 15 Col 16 Col 17
# 37  minute,     11  seconds   None   None   None   None   None
# 38  minute,     19  seconds   None   None   None   None   None

# %%
len(Cost_Speed_By_Country_Slpit_Filtered_df3)
# Out:
# 2

# %%
Cost_Speed_By_Country_Slpit_Filtered_df3['Renamed Country'] = ''
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Cost_Speed_By_Country_Slpit_Filtered_df3['Renamed Country']  = Cost_Speed_By_Country_Slpit_Filtered_df3['Col 1'].map(str) + ' ' + Cost_Speed_By_Country_Slpit_Filtered_df3['Col 2'].map(str) + ' ' + Cost_Speed_By_Country_Slpit_Filtered_df3['Col 3'].map(str)
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Cost_Speed_By_Country_Slpit_Filtered_df3['Col 1'] = Cost_Speed_By_Country_Slpit_Filtered_df3['Renamed Country']
Cost_Speed_By_Country_Slpit_Filtered_df3
# Out:
# C:\Users\LKNT\anaconda3\envs\LKNT\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    Col 1 Col 2     Col 3    Col 4  Col 5 Col 6  Col 7 Col 8  \
# 37   Trinidad and Tobago   and    Tobago   £48.01   42.5  Mbps  23.15  Mbps
# 38  United Arab Emirates  Arab  Emirates  £124.11  38.16  Mbps  13.56  Mbps
#
#    Col 9   Col 10 Col 11   Col 12 Col 13 Col 14 Col 15 Col 16 Col 17  \
# 37     1  minute,     11  seconds   None   None   None   None   None
# 38     1  minute,     19  seconds   None   None   None   None   None
#
#          Renamed Country
# 37   Trinidad and Tobago
# 38  United Arab Emirates

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df3 = Cost_Speed_By_Country_Slpit_Filtered_df3.drop(columns = ['Col 2', 'Col 3', 'Col 13', 'Col 14', 'Col 15', 'Col 16', 'Col 17', 'Renamed Country'])

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df3
# Out:
#                    Col 1    Col 4  Col 5 Col 6  Col 7 Col 8 Col 9   Col 10  \
# 37   Trinidad and Tobago   £48.01   42.5  Mbps  23.15  Mbps     1  minute,
# 38  United Arab Emirates  £124.11  38.16  Mbps  13.56  Mbps     1  minute,
#
#    Col 11   Col 12
# 37     11  seconds
# 38     19  seconds

# %%
Cost_Speed_By_Country_Slpit_Filtered_df1.head()
# Out:
#        Col 1   Col 2    Col 3 Col 4   Col 5     Col 6  Col 7    Col 8   Col 9  \
# 0    Country    Avg.  Monthly  Cost    Avg.  Download  Speed     Avg.  Upload
# 1  Singapore  £39.84   185.25  Mbps  192.08      Mbps     16  seconds    None
# 2    Iceland  £60.56    153.3  Mbps  155.46      Mbps     20  seconds    None
# 4    Hungary  £14.51   108.78  Mbps   44.44      Mbps     28  seconds    None
# 6     Sweden  £44.23   106.76  Mbps   72.98      Mbps     28  seconds    None
#
#   Col 10
# 0  Speed
# 1   None
# 2   None
# 4   None
# 6   None

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df2
# Out:
#              Col 1   Col 3   Col 4 Col 5  Col 6 Col 7 Col 8    Col 9 Col 10  \
# 3      South Korea  £25.51  114.31  Mbps   90.2  Mbps    26  seconds   None
# 5    United States  £53.48  107.28  Mbps  37.11  Mbps    28  seconds   None
# 16     New Zealand  £46.43   83.96  Mbps  47.63  Mbps    36  seconds   None
# 27  United Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54  seconds   None
# 35  Czech Republic  £20.49    44.6  Mbps   23.6  Mbps     1  minute,      7
# 43    Saudi Arabia  £75.62   29.83  Mbps  12.55  Mbps     1  minute,     41
#
#      Col 11
# 3      None
# 5      None
# 16     None
# 27     None
# 35  seconds
# 43  seconds

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df2 = Cost_Speed_By_Country_Slpit_Filtered_Drop_df2.rename(columns = {'Col 1' : 'Col 1', 
                                                                                                        'Col 3' : 'Col 2',
                                                                                                        'Col 4' : 'Col 3',
                                                                                                        'Col 5' : 'Col 4',
                                                                                                        'Col 6' : 'Col 5',
                                                                                                        'Col 7' : 'Col 6',
                                                                                                        'Col 8' : 'Col 7',
                                                                                                        'Col 9' : 'Col 8',
                                                                                                        'Col 10' : 'Col 9',
                                                                                                        'Col 11' : 'Col 10'
                                                                                                       }
                                                                                             )

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df2
# Out:
#              Col 1   Col 2   Col 3 Col 4  Col 5 Col 6 Col 7    Col 8 Col 9  \
# 3      South Korea  £25.51  114.31  Mbps   90.2  Mbps    26  seconds  None
# 5    United States  £53.48  107.28  Mbps  37.11  Mbps    28  seconds  None
# 16     New Zealand  £46.43   83.96  Mbps  47.63  Mbps    36  seconds  None
# 27  United Kingdom  £31.27   55.14  Mbps  12.72  Mbps    54  seconds  None
# 35  Czech Republic  £20.49    44.6  Mbps   23.6  Mbps     1  minute,     7
# 43    Saudi Arabia  £75.62   29.83  Mbps  12.55  Mbps     1  minute,    41
#
#      Col 10
# 3      None
# 5      None
# 16     None
# 27     None
# 35  seconds
# 43  seconds

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df3
# Out:
#                    Col 1    Col 4  Col 5 Col 6  Col 7 Col 8 Col 9   Col 10  \
# 37   Trinidad and Tobago   £48.01   42.5  Mbps  23.15  Mbps     1  minute,
# 38  United Arab Emirates  £124.11  38.16  Mbps  13.56  Mbps     1  minute,
#
#    Col 11   Col 12
# 37     11  seconds
# 38     19  seconds

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df3 = Cost_Speed_By_Country_Slpit_Filtered_Drop_df3.rename(columns = {'Col 1' : 'Col 1', 
                                                                                                        'Col 4' : 'Col 2',
                                                                                                        'Col 5' : 'Col 3',
                                                                                                        'Col 6' : 'Col 4',
                                                                                                        'Col 7' : 'Col 5',
                                                                                                        'Col 8' : 'Col 6',
                                                                                                        'Col 9' : 'Col 7',
                                                                                                        'Col 10' : 'Col 8',
                                                                                                        'Col 11' : 'Col 9',
                                                                                                        'Col 12' : 'Col 10'
                                                                                                       }
                                                                                             )

# %%
Cost_Speed_By_Country_Slpit_Filtered_Drop_df3
# Out:
#                    Col 1    Col 2  Col 3 Col 4  Col 5 Col 6 Col 7    Col 8  \
# 37   Trinidad and Tobago   £48.01   42.5  Mbps  23.15  Mbps     1  minute,
# 38  United Arab Emirates  £124.11  38.16  Mbps  13.56  Mbps     1  minute,
#
#    Col 9   Col 10
# 37    11  seconds
# 38    19  seconds

# %%
Cost_Speed_By_Country_concatenate_df = pd.concat([ Cost_Speed_By_Country_Slpit_Filtered_df1, Cost_Speed_By_Country_Slpit_Filtered_Drop_df2, Cost_Speed_By_Country_Slpit_Filtered_Drop_df3 ])
Cost_Speed_By_Country_concatenate_df
# Out:
#                    Col 1    Col 2    Col 3 Col 4   Col 5     Col 6  Col 7  \
# 0                Country     Avg.  Monthly  Cost    Avg.  Download  Speed
# 1              Singapore   £39.84   185.25  Mbps  192.08      Mbps     16
# 2                Iceland   £60.56    153.3  Mbps  155.46      Mbps     20
# 4                Hungary   £14.51   108.78  Mbps   44.44      Mbps     28
# 6                 Sweden   £44.23   106.76  Mbps   72.98      Mbps     28
# 7                  Spain   £33.48   105.03  Mbps   87.51      Mbps     29
# 8            Switzerland   £63.20    104.2  Mbps   65.37      Mbps     29
# 9             Luxembourg   £56.21   101.48  Mbps    65.5      Mbps     30
# 10                Norway   £58.40    98.72  Mbps   75.67      Mbps     30
# 11                France   £24.60    96.14  Mbps   49.05      Mbps     31
# 12               Denmark   £40.38    91.27  Mbps   67.11      Mbps     33
# 13                Canada   £45.55    91.05  Mbps   38.57      Mbps     33
# ...

# %%
len(Cost_Speed_By_Country_concatenate_df)
# Out:
# 55

# %%
Cost_Speed_By_Country_concatenate_df = Cost_Speed_By_Country_concatenate_df.drop(columns = ['Col 4', 'Col 6', 'Col 7', 'Col 8', 'Col 9', 'Col 10'])

# %%
Cost_Speed_By_Country_concatenate_df = Cost_Speed_By_Country_concatenate_df[Cost_Speed_By_Country_concatenate_df['Col 1'] != 'Country']

# %%
Cost_Speed_By_Country_concatenate_df
# Out:
#                    Col 1    Col 2   Col 3   Col 5
# 1              Singapore   £39.84  185.25  192.08
# 2                Iceland   £60.56   153.3  155.46
# 4                Hungary   £14.51  108.78   44.44
# 6                 Sweden   £44.23  106.76   72.98
# 7                  Spain   £33.48  105.03   87.51
# 8            Switzerland   £63.20   104.2   65.37
# 9             Luxembourg   £56.21  101.48    65.5
# 10                Norway   £58.40   98.72   75.67
# 11                France   £24.60   96.14   49.05
# 12               Denmark   £40.38   91.27   67.11
# 13                Canada   £45.55   91.05   38.57
# 14                 Japan   £29.35   88.97   97.52
# 15           Netherlands   £46.79   86.14   41.77
# 17              Portugal   £48.31   73.65   39.67
# 18             Lithuania   £13.30   71.37   63.07
# 19              Barbados   £88.37   70.37   38.45
# 20                Israel   £10.29   69.24   15.44
# 21               Germany   £28.98   65.19    15.8
# ...

# %%
Cost_Speed_By_Country_concatenate_df[['First','Last']] = Cost_Speed_By_Country_concatenate_df['Col 2'].str.split('£' , expand = True)
Cost_Speed_By_Country_concatenate_df['Col 2'] = Cost_Speed_By_Country_concatenate_df['Last']
Cost_Speed_By_Country_concatenate_df = Cost_Speed_By_Country_concatenate_df.drop(columns = ['First', 'Last'])

# %%
Cost_Speed_By_Country_concatenate_df
#Cost_Speed_By_Country_concatenate_df
# Out:
#                    Col 1   Col 2   Col 3   Col 5
# 1              Singapore   39.84  185.25  192.08
# 2                Iceland   60.56   153.3  155.46
# 4                Hungary   14.51  108.78   44.44
# 6                 Sweden   44.23  106.76   72.98
# 7                  Spain   33.48  105.03   87.51
# 8            Switzerland   63.20   104.2   65.37
# 9             Luxembourg   56.21  101.48    65.5
# 10                Norway   58.40   98.72   75.67
# 11                France   24.60   96.14   49.05
# 12               Denmark   40.38   91.27   67.11
# 13                Canada   45.55   91.05   38.57
# 14                 Japan   29.35   88.97   97.52
# 15           Netherlands   46.79   86.14   41.77
# 17              Portugal   48.31   73.65   39.67
# 18             Lithuania   13.30   71.37   63.07
# 19              Barbados   88.37   70.37   38.45
# 20                Israel   10.29   69.24   15.44
# 21               Germany   28.98   65.19    15.8
# ...

# %%
Cost_Speed_By_Country_concatenate_df = Cost_Speed_By_Country_concatenate_df.rename(columns = {'Col 1' : 'Country',
                                                                                              'Col 2' : 'Avg_Monthly_Cost_in_GBP',
                                                                                              'Col 3' : 'Avg_Download_Speed_Mbps',
                                                                                              'Col 5' : 'Avg_Upload_Speed_Mbps'
                                                                                                       }
                                                                                             )

# %%
Cost_Speed_By_Country_concatenate_df.dtypes
# Out:
# Country                    object
# Avg_Monthly_Cost_in_GBP    object
# Avg_Download_Speed_Mbps    object
# Avg_Upload_Speed_Mbps      object
# dtype: object

# %%
Cost_Speed_By_Country_concatenate_df['Country']                 = Cost_Speed_By_Country_concatenate_df['Country'].astype(str)
Cost_Speed_By_Country_concatenate_df['Avg_Monthly_Cost_in_GBP']        = pd.to_numeric(Cost_Speed_By_Country_concatenate_df['Avg_Monthly_Cost_in_GBP'])
Cost_Speed_By_Country_concatenate_df['Avg_Download_Speed_Mbps'] = pd.to_numeric(Cost_Speed_By_Country_concatenate_df['Avg_Download_Speed_Mbps'])
Cost_Speed_By_Country_concatenate_df['Avg_Upload_Speed_Mbps']   = pd.to_numeric(Cost_Speed_By_Country_concatenate_df['Avg_Upload_Speed_Mbps'])

# %%
Cost_Speed_By_Country_concatenate_df.dtypes
# Out:
# Country                     object
# Avg_Monthly_Cost_in_GBP    float64
# Avg_Download_Speed_Mbps    float64
# Avg_Upload_Speed_Mbps      float64
# dtype: object

# %%
Cost_Speed_By_Country_concatenate_df.head()
# Out:
#      Country  Avg_Monthly_Cost_in_GBP  Avg_Download_Speed_Mbps  \
# 1  Singapore                    39.84                   185.25
# 2    Iceland                    60.56                   153.30
# 4    Hungary                    14.51                   108.78
# 6     Sweden                    44.23                   106.76
# 7      Spain                    33.48                   105.03
#
#    Avg_Upload_Speed_Mbps
# 1                 192.08
# 2                 155.46
# 4                  44.44
# 6                  72.98
# 7                  87.51

# %%
# Export to CSV
Cost_Speed_By_Country_concatenate_df.to_csv("../../02_Data_Output/Internet_Cost_Speed_By_Country.csv",
                   index=False, 
                   header=True
                  )
